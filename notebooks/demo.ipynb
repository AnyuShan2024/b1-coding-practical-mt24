# %%
# Add relevant Jupyter notebook extensions

# %%
# Run this section to add scripts to path
import sys
import os

uuv_mission_dir = os.path.abspath('../uuv_mission')  # Adjust path as necessary
sys.path.append(uuv_mission_dir)

# %%
# You can double-check your Python path like this...
import sys

print(sys.path)
# Out:
# ['C:\\Users\\AnyuSHAN\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'C:\\Users\\AnyuSHAN\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'C:\\Users\\AnyuSHAN\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\Users\\AnyuSHAN\\AppData\\Local\\Programs\\Python\\Python310', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\venv', '', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\venv\\lib\\site-packages', 'd:\\oxfordprojects\\b1-coding-practical-mt24', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\venv\\lib\\site-packages\\win32', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\venv\\lib\\site-packages\\win32\\lib', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\venv\\lib\\site-packages\\Pythonwin', 'd:\\OxfordProjects\\b1-coding-practical-mt24\\uuv_mission']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.control import PDController
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission

sub = Submarine()

# Instantiate your controller (depending on your implementation)
ctrl = PDController(0.15, 0.6)

closed_loop = ClosedLoop(sub, ctrl)
mission = Mission.from_csv("mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
